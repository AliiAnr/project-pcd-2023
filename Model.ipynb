# %% [markdown]
# # Libraries

# %%
import os
import pathlib
import zipfile
import numpy as np
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import Model
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Directories

# %%
#Define dataset directory, train directory and test directory
dataset_dir = "forestsplt"
train_dir = "forestsplt/Train"
test_dir = "forestsplt/Test"

# %% [markdown]
# # Dataset Sample

# %%
#Show dataset sample from train dataset
#Initiate all directory in train folder
label_dirs = os.listdir(train_dir)

#initiate the figure and the axis to show the sample data images
fig, axs = plt.subplots(1, 3, figsize=(12, 3))

#Loop through all label directories and show 1 image for each label
for i, label_dir in enumerate(label_dirs):
    label_dir_path = os.path.join(train_dir, label_dir)
    image_files = os.listdir(label_dir_path)
    image_path = os.path.join(label_dir_path, image_files[0])
    image = Image.open(image_path)
    axs[i].imshow(image)
    axs[i].set_title(f'Sample {os.listdir(train_dir)[i]}')
    axs[i].axis('off')

# Show figure
plt.tight_layout()
plt.show()

# %% [markdown]
# # ImageDataGenerator

# %%
def image_generator(train_dir, test_dir):
  #Initiate the ImageDataGenerator class for training dataset
  #Define the augmentation value
  train_datagen = ImageDataGenerator()

  # Specify the method to load images from a directory and pass in the appropriate arguments:
  # - directory: should be a relative path to the directory containing the data
  # - targe_size: set this equal to the resolution of each image (excluding the color dimension)
  # - batch_size: number of images the generator yields when asked for a next batch. Set this to 10.
  # - class_mode: How the labels are represented. Should be one of "binary", "categorical" or "sparse".
  #               Pick the one that better suits here given that the labels are going to be 1D binary labels.
  train_generator = train_datagen.flow_from_directory(directory=train_dir,
                                                      target_size=(256, 256),
                                                      batch_size=16,
                                                      class_mode="categorical")

  #Initiate the ImageDataGenerator class fro testing dataset
  #Define the augmentation value
  test_datagen = ImageDataGenerator()

  # Pass in the appropriate arguments to the flow_from_directory method
  test_generator = test_datagen.flow_from_directory(directory=test_dir,
                                                    batch_size=16,
                                                    class_mode='categorical',
                                                    target_size=(256, 256))

  return train_generator, test_generator

# %%
train_generator, test_generator = image_generator(train_dir, test_dir)
# Out:
# Found 442 images belonging to 3 classes.
# Found 112 images belonging to 3 classes.

# %% [markdown]
# # Model

# %%
def create_uncompiled_model():
    inputs = layers.Input(shape=(256, 256, 3))

    # x = layers.Conv2D(32, (3, 3), activation='relu')(inputs)
    # Flatten the output layer to 1 dimension
    x = layers.Flatten()(inputs)
    # Add a fully connected layer with 1024 hidden units and ReLU activation
    x = layers.Dense(128, activation='relu')(x)
    # Add a dropout rate of 0.2
    x = layers.Dropout(0.2)(x)
    # Add a final sigmoid layer for classification
    x = layers.Dense(4, activation='softmax')(x)
    # Create the complete model by using the Model class
    model = Model(inputs=inputs, outputs=x)

    return model

# %%
uncompiled_model = create_uncompiled_model()

try:
  uncompiled_model.predict(train_generator)
except:
  print("Your current architecture is incompatible with the windowed dataset, try adjusting it!")
else:
  print("Your current architecture is compatible with the windowed dataset!")
# Out:
# 28/28 [==============================] - 2s 70ms/step
# Your current architecture is compatible with the windowed dataset!

# %%
def create_model():
  optimizer = tf.keras.optimizers.Adam()
  inputs = layers.Input(shape=(256, 256, 3))


  x = layers.Flatten()(inputs)
  # Add a fully connected layer with 128 hidden units and ReLU activation
  x = layers.Dense(128, activation='relu')(x)
  # Add a dropout rate
  x = layers.Dropout(0.2)(x)
  # Add a final sigmoid layer for classification
  x = x = layers.Dense(3, activation='softmax')(x)
  # Create the complete model by using the Model class
  model = Model(inputs=inputs, outputs=x)
  # Compile the model
  model.compile(optimizer = optimizer,
                loss = 'categorical_crossentropy',
                metrics = ['accuracy'])

  return model

# %%
myModel = create_model()

# %%
# Inspect parameters
total_params = myModel.count_params()
num_trainable_params = sum([w.shape.num_elements() for w in myModel.trainable_weights])

print(f"There are {total_params:,} total parameters in this model.")
print(f"There are {num_trainable_params:,} trainable parameters in this model.")
# Out:
# There are 25,166,339 total parameters in this model.
# There are 25,166,339 trainable parameters in this model.

# %% [markdown]
# # Training

# %%
history = myModel.fit(train_generator,
                    validation_data = test_generator,
                    epochs = 50,
                    callbacks=None,
                    verbose = 2)
# Out:
# Epoch 1/50
# 28/28 - 18s - loss: 10277.2002 - accuracy: 0.3507 - val_loss: 725.1948 - val_accuracy: 0.6875 - 18s/epoch - 650ms/step
# Epoch 2/50
# 28/28 - 12s - loss: 161.3478 - accuracy: 0.4140 - val_loss: 1.0897 - val_accuracy: 0.3839 - 12s/epoch - 441ms/step
# Epoch 3/50
# 28/28 - 11s - loss: 1.0982 - accuracy: 0.3733 - val_loss: 1.0894 - val_accuracy: 0.3839 - 11s/epoch - 384ms/step
# Epoch 4/50
# 28/28 - 11s - loss: 1.0980 - accuracy: 0.3733 - val_loss: 1.0891 - val_accuracy: 0.3839 - 11s/epoch - 397ms/step
# Epoch 5/50
# 28/28 - 11s - loss: 1.0977 - accuracy: 0.3733 - val_loss: 1.0888 - val_accuracy: 0.3839 - 11s/epoch - 393ms/step
# Epoch 6/50
# 28/28 - 11s - loss: 1.0974 - accuracy: 0.3733 - val_loss: 1.0885 - val_accuracy: 0.3839 - 11s/epoch - 385ms/step
# Epoch 7/50
# 28/28 - 10s - loss: 1.0971 - accuracy: 0.3733 - val_loss: 1.0883 - val_accuracy: 0.3839 - 10s/epoch - 371ms/step
# Epoch 8/50
# 28/28 - 10s - loss: 1.0969 - accuracy: 0.3733 - val_loss: 1.0879 - val_accuracy: 0.3839 - 10s/epoch - 366ms/step
# Epoch 9/50
# 28/28 - 11s - loss: 1.0966 - accuracy: 0.3733 - val_loss: 1.0877 - val_accuracy: 0.3839 - 11s/epoch - 377ms/step
# Epoch 10/50
# 28/28 - 11s - loss: 1.0964 - accuracy: 0.3733 - val_loss: 1.0875 - val_accuracy: 0.3839 - 11s/epoch - 384ms/step
# Epoch 11/50
# 28/28 - 11s - loss: 1.0962 - accuracy: 0.3733 - val_loss: 1.0872 - val_accuracy: 0.3839 - 11s/epoch - 377ms/step
# Epoch 12/50
# 28/28 - 11s - loss: 1.0961 - accuracy: 0.3733 - val_loss: 1.0870 - val_accuracy: 0.3839 - 11s/epoch - 377ms/step
# Epoch 13/50
# 28/28 - 10s - loss: 1.0959 - accuracy: 0.3733 - val_loss: 1.0868 - val_accuracy: 0.3839 - 10s/epoch - 368ms/step
# Epoch 14/50
# 28/28 - 11s - loss: 1.0957 - accuracy: 0.3733 - val_loss: 1.0867 - val_accuracy: 0.3839 - 11s/epoch - 381ms/step
# Epoch 15/50
# 28/28 - 11s - loss: 1.0956 - accuracy: 0.3733 - val_loss: 1.0865 - val_accuracy: 0.3839 - 11s/epoch - 376ms/step
# Epoch 16/50
# 28/28 - 10s - loss: 1.0955 - accuracy: 0.3733 - val_loss: 1.0863 - val_accuracy: 0.3839 - 10s/epoch - 364ms/step
# Epoch 17/50
# 28/28 - 10s - loss: 1.0954 - accuracy: 0.3733 - val_loss: 1.0863 - val_accuracy: 0.3839 - 10s/epoch - 355ms/step
# Epoch 18/50
# 28/28 - 15s - loss: 1.0953 - accuracy: 0.3733 - val_loss: 1.0861 - val_accuracy: 0.3839 - 15s/epoch - 546ms/step
# Epoch 19/50
# 28/28 - 21s - loss: 1.0952 - accuracy: 0.3733 - val_loss: 1.0861 - val_accuracy: 0.3839 - 21s/epoch - 765ms/step
# Epoch 20/50
# 28/28 - 21s - loss: 1.0952 - accuracy: 0.3733 - val_loss: 1.0859 - val_accuracy: 0.3839 - 21s/epoch - 759ms/step
# Epoch 21/50
# 28/28 - 21s - loss: 1.0951 - accuracy: 0.3733 - val_loss: 1.0858 - val_accuracy: 0.3839 - 21s/epoch - 759ms/step
# Epoch 22/50
# 28/28 - 21s - loss: 1.0951 - accuracy: 0.3733 - val_loss: 1.0857 - val_accuracy: 0.3839 - 21s/epoch - 761ms/step
# Epoch 23/50
# 28/28 - 21s - loss: 1.0949 - accuracy: 0.3733 - val_loss: 1.0857 - val_accuracy: 0.3839 - 21s/epoch - 764ms/step
# Epoch 24/50
# 28/28 - 21s - loss: 1.0949 - accuracy: 0.3733 - val_loss: 1.0857 - val_accuracy: 0.3839 - 21s/epoch - 744ms/step
# Epoch 25/50
# 28/28 - 21s - loss: 1.0950 - accuracy: 0.3733 - val_loss: 1.0856 - val_accuracy: 0.3839 - 21s/epoch - 759ms/step
# Epoch 26/50
# 28/28 - 18s - loss: 1.0949 - accuracy: 0.3733 - val_loss: 1.0855 - val_accuracy: 0.3839 - 18s/epoch - 637ms/step
# Epoch 27/50
# 28/28 - 21s - loss: 1.0948 - accuracy: 0.3733 - val_loss: 1.0855 - val_accuracy: 0.3839 - 21s/epoch - 756ms/step
# Epoch 28/50
# 28/28 - 21s - loss: 1.0948 - accuracy: 0.3733 - val_loss: 1.0855 - val_accuracy: 0.3839 - 21s/epoch - 764ms/step
# Epoch 29/50
# 28/28 - 21s - loss: 1.0948 - accuracy: 0.3733 - val_loss: 1.0855 - val_accuracy: 0.3839 - 21s/epoch - 742ms/step
# Epoch 30/50
# 28/28 - 21s - loss: 1.0947 - accuracy: 0.3733 - val_loss: 1.0855 - val_accuracy: 0.3839 - 21s/epoch - 758ms/step
# Epoch 31/50
# 28/28 - 21s - loss: 1.0947 - accuracy: 0.3733 - val_loss: 1.0854 - val_accuracy: 0.3839 - 21s/epoch - 738ms/step
# Epoch 32/50
# 28/28 - 21s - loss: 1.0948 - accuracy: 0.3733 - val_loss: 1.0854 - val_accuracy: 0.3839 - 21s/epoch - 761ms/step
# Epoch 33/50
# 28/28 - 21s - loss: 1.0948 - accuracy: 0.3733 - val_loss: 1.0854 - val_accuracy: 0.3839 - 21s/epoch - 759ms/step
# Epoch 34/50
# 28/28 - 20s - loss: 1.0947 - accuracy: 0.3733 - val_loss: 1.0854 - val_accuracy: 0.3839 - 20s/epoch - 709ms/step
# Epoch 35/50
# 28/28 - 22s - loss: 1.0948 - accuracy: 0.3733 - val_loss: 1.0853 - val_accuracy: 0.3839 - 22s/epoch - 769ms/step
# Epoch 36/50
# 28/28 - 21s - loss: 1.0948 - accuracy: 0.3733 - val_loss: 1.0854 - val_accuracy: 0.3839 - 21s/epoch - 737ms/step
# Epoch 37/50
# 28/28 - 22s - loss: 1.0947 - accuracy: 0.3733 - val_loss: 1.0853 - val_accuracy: 0.3839 - 22s/epoch - 773ms/step
# Epoch 38/50
# 28/28 - 21s - loss: 1.0948 - accuracy: 0.3733 - val_loss: 1.0853 - val_accuracy: 0.3839 - 21s/epoch - 748ms/step
# Epoch 39/50
# 28/28 - 21s - loss: 1.0946 - accuracy: 0.3733 - val_loss: 1.0853 - val_accuracy: 0.3839 - 21s/epoch - 751ms/step
# Epoch 40/50
# 28/28 - 21s - loss: 1.0947 - accuracy: 0.3733 - val_loss: 1.0853 - val_accuracy: 0.3839 - 21s/epoch - 752ms/step
# Epoch 41/50
# 28/28 - 21s - loss: 1.0947 - accuracy: 0.3733 - val_loss: 1.0853 - val_accuracy: 0.3839 - 21s/epoch - 747ms/step
# Epoch 42/50
# 28/28 - 19s - loss: 1.0947 - accuracy: 0.3733 - val_loss: 1.0853 - val_accuracy: 0.3839 - 19s/epoch - 695ms/step
# Epoch 43/50
# 28/28 - 21s - loss: 1.0946 - accuracy: 0.3733 - val_loss: 1.0853 - val_accuracy: 0.3839 - 21s/epoch - 748ms/step
# Epoch 44/50
# 28/28 - 21s - loss: 1.0947 - accuracy: 0.3733 - val_loss: 1.0853 - val_accuracy: 0.3839 - 21s/epoch - 743ms/step
# Epoch 45/50
# 28/28 - 21s - loss: 1.0946 - accuracy: 0.3733 - val_loss: 1.0853 - val_accuracy: 0.3839 - 21s/epoch - 737ms/step
# Epoch 46/50
# 28/28 - 21s - loss: 1.0947 - accuracy: 0.3733 - val_loss: 1.0853 - val_accuracy: 0.3839 - 21s/epoch - 737ms/step
# Epoch 47/50
# 28/28 - 21s - loss: 1.0947 - accuracy: 0.3733 - val_loss: 1.0852 - val_accuracy: 0.3839 - 21s/epoch - 741ms/step
# Epoch 48/50
# 28/28 - 21s - loss: 1.0948 - accuracy: 0.3733 - val_loss: 1.0853 - val_accuracy: 0.3839 - 21s/epoch - 744ms/step
# Epoch 49/50
# 28/28 - 20s - loss: 1.0946 - accuracy: 0.3733 - val_loss: 1.0853 - val_accuracy: 0.3839 - 20s/epoch - 713ms/step
# Epoch 50/50
# 28/28 - 21s - loss: 1.0947 - accuracy: 0.3733 - val_loss: 1.0853 - val_accuracy: 0.3839 - 21s/epoch - 736ms/step

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1,len(loss)+1)

plt.plot(epochs,loss,'y',label = 'Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(1,len(loss)+1)

plt.plot(epochs,acc,'y',label = 'Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation acc')
plt.xlabel('epoch')
plt.ylabel('acc')
plt.legend()
plt.show()
